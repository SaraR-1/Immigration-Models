# %%
from geopy.distance import vincenty, great_circle
from geopy.geocoders import Nominatim
import googlemaps

# %%
geolocator = Nominatim()

# %%
location = geolocator.geocode("Roma")
print((location.latitude, location.longitude))
# Out:
# (41.8933203, 12.4829321)

# %%
print(vincenty((geolocator.geocode("Roma").latitude, geolocator.geocode("Roma").longitude), (geolocator.geocode("Milano").latitude, geolocator.geocode("Milano").longitude)).meters)
# Out:
# 477520.65411504783

# %%
print(great_circle((geolocator.geocode("Roma").latitude, geolocator.geocode("Roma").longitude), (geolocator.geocode("Milano").latitude, geolocator.geocode("Milano").longitude)).meters)
# Out:
# 477519.8908643832

# %%
gmaps = googlemaps.googlemaps("AIzaSyDBoq3DSmjrHrrKqF7G5K05o-31rSYonZA")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-96f38c87c667> in <module>()
# ----> 1 gmaps = googlemaps.googlemaps("AIzaSyDBoq3DSmjrHrrKqF7G5K05o-31rSYonZA")
#
# TypeError: 'module' object is not callable

# %%
geolocator.geocode("Cagliari").latitude, geolocator.geocode("Cagliari").longitude
# Out:
# (39.2169525, 9.1128513)

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDBoq3DSmjrHrrKqF7G5K05o-31rSYonZA')


now = datetime.now()
directions_result = gmaps.directions("41.8933203, 12.4829321",
                                     "39.2169525, 9.1128513",
                                     #mode="driving",
                                     avoid="ferries",
                                     departure_time=now
                                    )

print(directions_result[0]['legs'][0]['distance']['text'])
print(directions_result[0]['legs'][0]['duration']['text'])
# Out:
# 867 km
# 16 hours 26 mins

# %%
directions_result
# Out:
# [{'bounds': {'northeast': {'lat': 43.0155566, 'lng': 12.4826393},
#    'southwest': {'lat': 39.2169134, 'lng': 8.612155}},
#   'copyrights': 'Map data ©2018 Google',
#   'legs': [{'distance': {'text': '867 km', 'value': 867368},
#     'duration': {'text': '16 hours 26 mins', 'value': 59172},
#     'duration_in_traffic': {'text': '16 hours 8 mins', 'value': 58051},
#     'end_address': 'Largo Carlo Felice, 74, 09124 Cagliari CA, Italy',
#     'end_location': {'lat': 39.2169134, 'lng': 9.1129166},
#     'start_address': 'Via delle Tre Pile, 2, 00186 Roma RM, Italy',
#     'start_location': {'lat': 41.8933122, 'lng': 12.4826393},
#     'steps': [{'distance': {'text': '39 m', 'value': 39},
#       'duration': {'text': '1 min', 'value': 8},
#       'end_location': {'lat': 41.89315120000001, 'lng': 12.4822631},
#       'html_instructions': 'Head <b>west</b> on <b>Via delle Tre Pile</b>',
#       'polyline': {'points': 'ehu~Fo_ekA?HAJ?B@@?B?@VX@B@B@B@B'},
# ...
