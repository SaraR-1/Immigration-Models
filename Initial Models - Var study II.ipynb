# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from collections import defaultdict
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import pycountry
import plot_data_functions as pdf

# %%
data_ = pd.read_table("/home/sara/Documents/Immigration/Shared_models/Data/countries_info.csv", sep = "\t", index_col=[0,1])
unesco_edu = pd.read_table("/home/sara/Documents/Immigration/Shared_statistics/Data_final/unesco_education.csv")
resident_foreigners_norm = pd.read_table("/home/sara/Documents/Immigration/Shared_statistics/Data_final/resident_foreigners_norm.csv")
geo_info = pd.read_table("/home/sara/Documents/Immigration/Shared_statistics/Data_final/cepii_geo_info.csv")
geo_dist = pd.read_table("/home/sara/Documents/Immigration/Shared_statistics/Data_final/cepii_geo_dist_norm.csv")
palette_continent = json.load(open('/home/sara/Documents/Immigration/Shared_statistics/Statistics/color_continent_dict.json'))

geo_dist_it = geo_dist[geo_dist["iso_o"] == "ITA"]

# %%
data_.head()
# Out:
#            Total population   Population aged 15-24 years   \
# Year iso3
# 2003 AFG           22507.368                      4418.412
#      AGO           16691.395                      3218.494
#      ALB            3117.045                       546.475
#      AND              75.643                         8.664
#      ARE            3625.798                       690.497
#
#            Population aged 65 years or older   \
# Year iso3
# 2003 AFG                              492.671
#      AGO                              401.786
#      ALB                              247.265
#      AND                                9.189
#      ARE                               34.296
#
#            Population aged 14 years or younger   Population aged 25-64 years   \
# Year iso3
# 2003 AFG                              10833.213                      6763.072
#      AGO                               8022.938                      5048.177
# ...

# %%
palette = ['y', 'green', 'darkgreen', 'yellowgreen', 'gold', 'orange', 'lightcoral', 'red', 'paleturquoise', 'deepskyblue', 'lightskyblue', 'blue', 'mediumpurple', 'rebeccapurple', 'fuchsia']
countries_list = ["Romania", "Morocco", "Albania", "Tunisia", "Egypt", "Ecuador", "Peru", "China", "Philippines"]
countries_list = [pycountry.countries.get(name=country).alpha_3 for country in countries_list]

# %% [markdown]
# Some indicators cannot be used due to missing data over the years.

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[:5], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS Population data",  True, "Plots/stock_vs_country_dem_info1_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[5:6], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS Total debt service", True, "Plots/stock_vs_country_dem_info2_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[6:14], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS GDP data",  True, "Plots/stock_vs_country_dem_info3_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[14:18], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS GDP per capita",  True, "Plots/stock_vs_country_dem_info4_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[18:19], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS GNI",  True, "Plots/stock_vs_country_dem_info5_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[19:22], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS GNI per capita",  True, "Plots/stock_vs_country_dem_info6_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[22:23], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS DEC",  True, "Plots/stock_vs_country_dem_info7_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[23:27], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS GNI per capita",  True, "Plots/stock_vs_country_dem_info8_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[23:24], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS PPP conversion factor",  True, "Plots/stock_vs_country_dem_info9_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[24:25], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS Mortality rate - infant",  True, "Plots/stock_vs_country_dem_info10_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[25:26], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS Population growth",  True, "Plots/stock_vs_country_dem_info11_")

# %%
pdf.relation_plot_time_variant_intern_function(data_, countries_list, data_.index.levels[0].tolist()[2:], data_.columns.tolist()[26:], resident_foreigners_norm.groupby(["Country", "Year"]), plt.figure(1, figsize=(15,14)), 331, 45, palette, None, "Immigrant Stock VS General government tot expenditure", True, "Plots/stock_vs_country_dem_info12_")
