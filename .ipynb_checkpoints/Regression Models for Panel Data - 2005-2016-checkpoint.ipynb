# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
import numpy as np
from statsmodels.datasets import grunfeld
from linearmodels.panel  import PanelOLS
import pandas as pd
import build_data_functions as bdf
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import model_functions as mf
import plot_model_functions as pmf
import panelOLS_models 
import statsmodels.api as sm
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

# %%
years = list(range(2005, 2017))

# %%
y = pd.read_table("/home/sara/Documents/Immigration/Shared_models/Data/resident_foreigners_norm.csv", sep = "\t", index_col=0)
y = y.groupby(["Province", "Country", "Year"], as_index=False)["Value"].sum()
y = bdf.pivot(y, "Country", "Value")

# %% [markdown]
# ## Zone level

# %%
xs = pd.read_table("/home/sara/Documents/Immigration/Shared_models/Data/x_zones.csv", sep = "\t", index_col=["Province", "Year"])

# %% [markdown]
# #### Feature selection
# Select features according to the k highest scores. The score function used is mutual information.

# %% [markdown]
# ### ROMANIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Romania", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.983000.
# Adjusted R-squared 0.982000.
# y_prev_1    1.074432
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.982000.
# Adjusted R-squared 0.982000.
# y_prev_1    1.084406
# Name: parameter, dtype: float64
# -------------------- Previous 2 Times --------------------
# R-squared 0.984000.
# Adjusted R-squared 0.984000.
# y_prev_1    1.362724
# y_prev_2   -0.320482
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.984000.
# Adjusted R-squared 0.984000.
# y_prev_1    1.359330
# y_prev_2   -0.308215
# Name: parameter, dtype: float64
# ------------- Variable Selection  Plot based -------------
# R-squared 0.988000.
# Adjusted R-squared 0.988000.
# y_prev_1                                                      1.001708
# y_prev_2                                                     -0.118216
# native population - Total                                    -0.010692
# Free activities in voluntary associations                     0.509519
# Meetings in cultural, recreational or other associations     27.937886
# Disposable Income                                            14.357621
# Average monthly expenditure for housing                     100.526036
# unemployment - Total                                        -20.429506
# reach_difficulty - Emergency room                             7.365240
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.986000.
# Adjusted R-squared 0.986000.
# y_prev_1                                                     0.837720
# y_prev_2                                                     0.006282
# native population - Total                                   -0.012598
# Free activities in voluntary associations                  -15.846949
# Meetings in cultural, recreational or other associations    43.803821
# Disposable Income                                           19.497670
# Average monthly expenditure for housing                    -51.705702
# unemployment - Total                                       -60.310417
# reach_difficulty - Emergency room                            8.720998
# Name: parameter, dtype: float64
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.986000.
# Adjusted R-squared 0.986000.
# y_prev_2                            -0.229003
# y_prev_1                             1.213584
# Average age of mothers at birth    468.159117
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.986000.
# Adjusted R-squared 0.986000.
# y_prev_2                            -0.209980
# y_prev_1                             1.186513
# Average age of mothers at birth    524.506499
# Name: parameter, dtype: float64
# --------------------- k = 5 ---------------------
# R-squared 0.987000.
# Adjusted R-squared 0.987000.
# y_prev_2                                        -0.224902
# y_prev_1                                         1.135104
# Free activities in voluntary associations       19.771076
# Average age of fathers at birth             -26923.197001
# Average age of mothers at birth              30294.227373
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.987000.
# Adjusted R-squared 0.986000.
# y_prev_2                                        -0.201623
# y_prev_1                                         1.067903
# Free activities in voluntary associations       28.329793
# Average age of fathers at birth             -49289.944008
# Average age of mothers at birth              55284.920841
# Name: parameter, dtype: float64
# --------------------- k = 7 ---------------------
# R-squared 0.987000.
# Adjusted R-squared 0.987000.
# y_prev_2                                        -0.227655
# y_prev_1                                         1.112534
# Other goods and services                        20.335824
# Communications                                 -67.168660
# Free activities in voluntary associations       22.013302
# Average age of fathers at birth             -31302.563138
# Average age of mothers at birth              35337.353310
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.985000.
# Adjusted R-squared 0.985000.
# y_prev_2                                        -0.190774
# y_prev_1                                         0.974519
# Other goods and services                        16.785696
# Communications                                -100.723715
# Free activities in voluntary associations       44.505492
# Average age of fathers at birth             -66271.533574
# Average age of mothers at birth              74630.324576
# Name: parameter, dtype: float64
# --------------------- k = 10 ---------------------
# R-squared 0.989000.
# Adjusted R-squared 0.989000.
# y_prev_2                                        -0.269565
# y_prev_1                                         1.002437
# internal_migration - Foreign country             0.098077
# reach_difficulty - Pharmacy                    -59.797113
# Disposable Income                               18.357132
# Other goods and services                       153.936650
# Communications                                -431.196197
# Free activities in voluntary associations      -35.253609
# Average age of fathers at birth             -34073.089129
# Average age of mothers at birth              37911.959955
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.985000.
# Adjusted R-squared 0.985000.
# y_prev_2                                        -0.171479
# y_prev_1                                         0.799674
# internal_migration - Foreign country            -0.840176
# reach_difficulty - Pharmacy                    -56.561087
# Disposable Income                               26.865588
# Other goods and services                       299.458020
# Communications                                -869.425959
# Free activities in voluntary associations       -0.775039
# Average age of fathers at birth             -30346.083536
# Average age of mothers at birth              32634.864967
# Name: parameter, dtype: float64
# --------------------- k = 15 ---------------------
# R-squared 0.992000.
# Adjusted R-squared 0.992000.
# y_prev_2                                        -0.189361
# y_prev_1                                         0.803086
# internal_migration - Foreign country             0.017580
# reach_difficulty - Pharmacy                     25.445744
# reach_difficulty - Emergency room              -18.944566
# unemployment - Total                           -78.801010
# Born alive                                      -1.175509
# Disposable Income                               34.269065
# Clothing and footwear                         -150.303376
# Other goods and services                       247.430078
# Communications                                  22.785112
# Transport                                     -109.532063
# Free activities in voluntary associations       -9.027229
# Average age of fathers at birth             -67849.756099
# Average age of mothers at birth              75046.306540
# Name: parameter, dtype: float64
# ---------------- Training Results ----------------
# ---------------- Overall Results ----------------
# R-squared 0.990000.
# Adjusted R-squared 0.990000.
# y_prev_2                                        -0.031745
# y_prev_1                                         0.686895
# internal_migration - Foreign country            -1.165016
# reach_difficulty - Pharmacy                    -39.905533
# reach_difficulty - Emergency room               27.943270
# unemployment - Total                          -109.413410
# Born alive                                      -0.810541
# Disposable Income                               32.520173
# Clothing and footwear                         -197.273459
# Other goods and services                       247.427992
# Communications                                -163.743638
# Transport                                      -43.753204
# Free activities in voluntary associations       18.445971
# Average age of fathers at birth             -39339.754171
# Average age of mothers at birth              42023.009394
# Name: parameter, dtype: float64

# %% [markdown]
# ### MOROCCO

# %%
panelOLS_models.panel_regression(y, xs, years, "Morocco", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.995873.
# Adjusted R-squared 0.995802.
# ---------------- Training Results ----------------
# R-squared 0.996014.
# Adjusted R-squared 0.995931.
# ---------------- Overall Results ----------------
# R-squared 0.995643.
# Adjusted R-squared 0.995568.
# ---------------- Training Results ----------------
# R-squared 0.995506.
# Adjusted R-squared 0.995401.
# ---------------- Overall Results ----------------
# R-squared 0.995680.
# Adjusted R-squared 0.995606.
# -------------------- Previous 2 Times --------------------
# R-squared 0.996500.
# Adjusted R-squared 0.996440.
# ---------------- Training Results ----------------
# R-squared 0.996420.
# Adjusted R-squared 0.996345.
# ---------------- Overall Results ----------------
# R-squared 0.996307.
# Adjusted R-squared 0.996244.
# ---------------- Training Results ----------------
# R-squared 0.995969.
# Adjusted R-squared 0.995875.
# ---------------- Overall Results ----------------
# R-squared 0.996351.
# Adjusted R-squared 0.996288.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.997302.
# Adjusted R-squared 0.997255.
# ---------------- Training Results ----------------
# R-squared 0.997455.
# Adjusted R-squared 0.997402.
# ---------------- Overall Results ----------------
# R-squared 0.996784.
# Adjusted R-squared 0.996728.
# ---------------- Training Results ----------------
# R-squared 0.997339.
# Adjusted R-squared 0.997277.
# ---------------- Overall Results ----------------
# R-squared 0.996943.
# Adjusted R-squared 0.996890.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.996765.
# Adjusted R-squared 0.996709.
# ---------------- Training Results ----------------
# R-squared 0.996751.
# Adjusted R-squared 0.996683.
# ---------------- Overall Results ----------------
# R-squared 0.996566.
# Adjusted R-squared 0.996507.
# ---------------- Training Results ----------------
# R-squared 0.996314.
# Adjusted R-squared 0.996228.
# ---------------- Overall Results ----------------
# R-squared 0.996616.
# Adjusted R-squared 0.996558.
# --------------------- k = 5 ---------------------
# R-squared 0.996881.
# Adjusted R-squared 0.996827.
# ---------------- Training Results ----------------
# R-squared 0.997156.
# Adjusted R-squared 0.997096.
# ---------------- Overall Results ----------------
# R-squared 0.995864.
# Adjusted R-squared 0.995792.
# ---------------- Training Results ----------------
# R-squared 0.996785.
# Adjusted R-squared 0.996710.
# ---------------- Overall Results ----------------
# R-squared 0.995858.
# Adjusted R-squared 0.995787.
# --------------------- k = 7 ---------------------
# R-squared 0.996912.
# Adjusted R-squared 0.996859.
# ---------------- Training Results ----------------
# R-squared 0.997201.
# Adjusted R-squared 0.997143.
# ---------------- Overall Results ----------------
# R-squared 0.995782.
# Adjusted R-squared 0.995709.
# ---------------- Training Results ----------------
# R-squared 0.996860.
# Adjusted R-squared 0.996787.
# ---------------- Overall Results ----------------
# R-squared 0.995862.
# Adjusted R-squared 0.995791.
# --------------------- k = 10 ---------------------
# R-squared 0.997448.
# Adjusted R-squared 0.997404.
# ---------------- Training Results ----------------
# R-squared 0.998240.
# Adjusted R-squared 0.998203.
# ---------------- Overall Results ----------------
# R-squared 0.995834.
# Adjusted R-squared 0.995762.
# ---------------- Training Results ----------------
# R-squared 0.998151.
# Adjusted R-squared 0.998108.
# ---------------- Overall Results ----------------
# R-squared 0.995876.
# Adjusted R-squared 0.995804.
# --------------------- k = 15 ---------------------
# R-squared 0.998684.
# Adjusted R-squared 0.998661.
# ---------------- Training Results ----------------
# R-squared 0.999017.
# Adjusted R-squared 0.998996.
# ---------------- Overall Results ----------------
# R-squared 0.996936.
# Adjusted R-squared 0.996884.
# ---------------- Training Results ----------------
# R-squared 0.998903.
# Adjusted R-squared 0.998877.
# ---------------- Overall Results ----------------
# R-squared 0.996752.
# Adjusted R-squared 0.996696.

# %% [markdown]
# ### ALBANIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Albania", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.996436.
# Adjusted R-squared 0.996375.
# ---------------- Training Results ----------------
# R-squared 0.997005.
# Adjusted R-squared 0.996943.
# ---------------- Overall Results ----------------
# R-squared 0.996114.
# Adjusted R-squared 0.996047.
# ---------------- Training Results ----------------
# R-squared 0.996594.
# Adjusted R-squared 0.996515.
# ---------------- Overall Results ----------------
# R-squared 0.996186.
# Adjusted R-squared 0.996120.
# -------------------- Previous 2 Times --------------------
# R-squared 0.997703.
# Adjusted R-squared 0.997664.
# ---------------- Training Results ----------------
# R-squared 0.997965.
# Adjusted R-squared 0.997923.
# ---------------- Overall Results ----------------
# R-squared 0.997467.
# Adjusted R-squared 0.997424.
# ---------------- Training Results ----------------
# R-squared 0.997797.
# Adjusted R-squared 0.997746.
# ---------------- Overall Results ----------------
# R-squared 0.997589.
# Adjusted R-squared 0.997548.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.998060.
# Adjusted R-squared 0.998027.
# ---------------- Training Results ----------------
# R-squared 0.998209.
# Adjusted R-squared 0.998171.
# ---------------- Overall Results ----------------
# R-squared 0.997693.
# Adjusted R-squared 0.997654.
# ---------------- Training Results ----------------
# R-squared 0.998286.
# Adjusted R-squared 0.998246.
# ---------------- Overall Results ----------------
# R-squared 0.997840.
# Adjusted R-squared 0.997802.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.997753.
# Adjusted R-squared 0.997715.
# ---------------- Training Results ----------------
# R-squared 0.997991.
# Adjusted R-squared 0.997949.
# ---------------- Overall Results ----------------
# R-squared 0.997520.
# Adjusted R-squared 0.997477.
# ---------------- Training Results ----------------
# R-squared 0.997834.
# Adjusted R-squared 0.997783.
# ---------------- Overall Results ----------------
# R-squared 0.997646.
# Adjusted R-squared 0.997606.
# --------------------- k = 5 ---------------------
# R-squared 0.997963.
# Adjusted R-squared 0.997928.
# ---------------- Training Results ----------------
# R-squared 0.998127.
# Adjusted R-squared 0.998088.
# ---------------- Overall Results ----------------
# R-squared 0.996994.
# Adjusted R-squared 0.996942.
# ---------------- Training Results ----------------
# R-squared 0.997961.
# Adjusted R-squared 0.997914.
# ---------------- Overall Results ----------------
# R-squared 0.997271.
# Adjusted R-squared 0.997224.
# --------------------- k = 7 ---------------------
# R-squared 0.998457.
# Adjusted R-squared 0.998431.
# ---------------- Training Results ----------------
# R-squared 0.998506.
# Adjusted R-squared 0.998475.
# ---------------- Overall Results ----------------
# R-squared 0.997781.
# Adjusted R-squared 0.997743.
# ---------------- Training Results ----------------
# R-squared 0.998579.
# Adjusted R-squared 0.998546.
# ---------------- Overall Results ----------------
# R-squared 0.998209.
# Adjusted R-squared 0.998178.
# --------------------- k = 10 ---------------------
# R-squared 0.998556.
# Adjusted R-squared 0.998531.
# ---------------- Training Results ----------------
# R-squared 0.998751.
# Adjusted R-squared 0.998725.
# ---------------- Overall Results ----------------
# R-squared 0.997187.
# Adjusted R-squared 0.997139.
# ---------------- Training Results ----------------
# R-squared 0.998977.
# Adjusted R-squared 0.998953.
# ---------------- Overall Results ----------------
# R-squared 0.998057.
# Adjusted R-squared 0.998023.
# --------------------- k = 15 ---------------------
# R-squared 0.999101.
# Adjusted R-squared 0.999085.
# ---------------- Training Results ----------------
# R-squared 0.999544.
# Adjusted R-squared 0.999535.
# ---------------- Overall Results ----------------
# R-squared 0.996730.
# Adjusted R-squared 0.996674.
# ---------------- Training Results ----------------
# R-squared 0.999616.
# Adjusted R-squared 0.999607.
# ---------------- Overall Results ----------------
# R-squared 0.998498.
# Adjusted R-squared 0.998472.

# %% [markdown]
# ### TUNISIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Tunisia", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.990931.
# Adjusted R-squared 0.990775.
# ---------------- Training Results ----------------
# R-squared 0.989526.
# Adjusted R-squared 0.989308.
# ---------------- Overall Results ----------------
# R-squared 0.990882.
# Adjusted R-squared 0.990725.
# ---------------- Training Results ----------------
# R-squared 0.988953.
# Adjusted R-squared 0.988696.
# ---------------- Overall Results ----------------
# R-squared 0.990931.
# Adjusted R-squared 0.990775.
# -------------------- Previous 2 Times --------------------
# R-squared 0.991079.
# Adjusted R-squared 0.990925.
# ---------------- Training Results ----------------
# R-squared 0.989702.
# Adjusted R-squared 0.989487.
# ---------------- Overall Results ----------------
# R-squared 0.991030.
# Adjusted R-squared 0.990875.
# ---------------- Training Results ----------------
# R-squared 0.989114.
# Adjusted R-squared 0.988861.
# ---------------- Overall Results ----------------
# R-squared 0.991078.
# Adjusted R-squared 0.990924.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.994645.
# Adjusted R-squared 0.994552.
# ---------------- Training Results ----------------
# R-squared 0.993835.
# Adjusted R-squared 0.993706.
# ---------------- Overall Results ----------------
# R-squared 0.994506.
# Adjusted R-squared 0.994411.
# ---------------- Training Results ----------------
# R-squared 0.994135.
# Adjusted R-squared 0.993999.
# ---------------- Overall Results ----------------
# R-squared 0.993849.
# Adjusted R-squared 0.993743.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.991646.
# Adjusted R-squared 0.991502.
# ---------------- Training Results ----------------
# R-squared 0.990521.
# Adjusted R-squared 0.990323.
# ---------------- Overall Results ----------------
# R-squared 0.991591.
# Adjusted R-squared 0.991446.
# ---------------- Training Results ----------------
# R-squared 0.990343.
# Adjusted R-squared 0.990119.
# ---------------- Overall Results ----------------
# R-squared 0.991520.
# Adjusted R-squared 0.991374.
# --------------------- k = 5 ---------------------
# R-squared 0.993274.
# Adjusted R-squared 0.993158.
# ---------------- Training Results ----------------
# R-squared 0.992452.
# Adjusted R-squared 0.992294.
# ---------------- Overall Results ----------------
# R-squared 0.993222.
# Adjusted R-squared 0.993105.
# ---------------- Training Results ----------------
# R-squared 0.993558.
# Adjusted R-squared 0.993408.
# ---------------- Overall Results ----------------
# R-squared 0.992685.
# Adjusted R-squared 0.992559.
# --------------------- k = 7 ---------------------
# R-squared 0.993309.
# Adjusted R-squared 0.993194.
# ---------------- Training Results ----------------
# R-squared 0.992953.
# Adjusted R-squared 0.992806.
# ---------------- Overall Results ----------------
# R-squared 0.992553.
# Adjusted R-squared 0.992425.
# ---------------- Training Results ----------------
# R-squared 0.993659.
# Adjusted R-squared 0.993512.
# ---------------- Overall Results ----------------
# R-squared 0.992838.
# Adjusted R-squared 0.992715.
# --------------------- k = 10 ---------------------
# R-squared 0.993737.
# Adjusted R-squared 0.993629.
# ---------------- Training Results ----------------
# R-squared 0.994231.
# Adjusted R-squared 0.994110.
# ---------------- Overall Results ----------------
# R-squared 0.992032.
# Adjusted R-squared 0.991895.
# ---------------- Training Results ----------------
# R-squared 0.994306.
# Adjusted R-squared 0.994174.
# ---------------- Overall Results ----------------
# R-squared 0.992785.
# Adjusted R-squared 0.992661.
# --------------------- k = 15 ---------------------
# R-squared 0.994022.
# Adjusted R-squared 0.993919.
# ---------------- Training Results ----------------
# R-squared 0.994636.
# Adjusted R-squared 0.994525.
# ---------------- Overall Results ----------------
# R-squared 0.990500.
# Adjusted R-squared 0.990336.
# ---------------- Training Results ----------------
# R-squared 0.995520.
# Adjusted R-squared 0.995416.
# ---------------- Overall Results ----------------
# R-squared 0.982878.
# Adjusted R-squared 0.982583.

# %% [markdown]
# ### EGYPT

# %%
panelOLS_models.panel_regression(y, xs, years, "Egypt", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.984170.
# Adjusted R-squared 0.983897.
# ---------------- Training Results ----------------
# R-squared 0.978045.
# Adjusted R-squared 0.977588.
# ---------------- Overall Results ----------------
# R-squared 0.984169.
# Adjusted R-squared 0.983896.
# ---------------- Training Results ----------------
# R-squared 0.978226.
# Adjusted R-squared 0.977720.
# ---------------- Overall Results ----------------
# R-squared 0.983664.
# Adjusted R-squared 0.983382.
# -------------------- Previous 2 Times --------------------
# R-squared 0.984217.
# Adjusted R-squared 0.983945.
# ---------------- Training Results ----------------
# R-squared 0.978133.
# Adjusted R-squared 0.977678.
# ---------------- Overall Results ----------------
# R-squared 0.984213.
# Adjusted R-squared 0.983941.
# ---------------- Training Results ----------------
# R-squared 0.978689.
# Adjusted R-squared 0.978194.
# ---------------- Overall Results ----------------
# R-squared 0.983403.
# Adjusted R-squared 0.983117.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.985290.
# Adjusted R-squared 0.985037.
# ---------------- Training Results ----------------
# R-squared 0.980352.
# Adjusted R-squared 0.979943.
# ---------------- Overall Results ----------------
# R-squared 0.984971.
# Adjusted R-squared 0.984712.
# ---------------- Training Results ----------------
# R-squared 0.983957.
# Adjusted R-squared 0.983584.
# ---------------- Overall Results ----------------
# R-squared 0.979239.
# Adjusted R-squared 0.978881.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.984373.
# Adjusted R-squared 0.984104.
# ---------------- Training Results ----------------
# R-squared 0.978359.
# Adjusted R-squared 0.977908.
# ---------------- Overall Results ----------------
# R-squared 0.984365.
# Adjusted R-squared 0.984095.
# ---------------- Training Results ----------------
# R-squared 0.978997.
# Adjusted R-squared 0.978509.
# ---------------- Overall Results ----------------
# R-squared 0.983481.
# Adjusted R-squared 0.983196.
# --------------------- k = 5 ---------------------
# R-squared 0.985020.
# Adjusted R-squared 0.984762.
# ---------------- Training Results ----------------
# R-squared 0.979534.
# Adjusted R-squared 0.979108.
# ---------------- Overall Results ----------------
# R-squared 0.984937.
# Adjusted R-squared 0.984677.
# ---------------- Training Results ----------------
# R-squared 0.980208.
# Adjusted R-squared 0.979748.
# ---------------- Overall Results ----------------
# R-squared 0.983634.
# Adjusted R-squared 0.983352.
# --------------------- k = 7 ---------------------
# R-squared 0.986976.
# Adjusted R-squared 0.986752.
# ---------------- Training Results ----------------
# R-squared 0.983426.
# Adjusted R-squared 0.983081.
# ---------------- Overall Results ----------------
# R-squared 0.984752.
# Adjusted R-squared 0.984489.
# ---------------- Training Results ----------------
# R-squared 0.985032.
# Adjusted R-squared 0.984684.
# ---------------- Overall Results ----------------
# R-squared 0.983345.
# Adjusted R-squared 0.983058.
# --------------------- k = 10 ---------------------
# R-squared 0.988018.
# Adjusted R-squared 0.987812.
# ---------------- Training Results ----------------
# R-squared 0.985445.
# Adjusted R-squared 0.985142.
# ---------------- Overall Results ----------------
# R-squared 0.985278.
# Adjusted R-squared 0.985024.
# ---------------- Training Results ----------------
# R-squared 0.986719.
# Adjusted R-squared 0.986410.
# ---------------- Overall Results ----------------
# R-squared 0.982812.
# Adjusted R-squared 0.982516.
# --------------------- k = 15 ---------------------
# R-squared 0.988676.
# Adjusted R-squared 0.988481.
# ---------------- Training Results ----------------
# R-squared 0.985972.
# Adjusted R-squared 0.985679.
# ---------------- Overall Results ----------------
# R-squared 0.986311.
# Adjusted R-squared 0.986075.
# ---------------- Training Results ----------------
# R-squared 0.988055.
# Adjusted R-squared 0.987778.
# ---------------- Overall Results ----------------
# R-squared 0.966470.
# Adjusted R-squared 0.965892.

# %% [markdown]
# ### ECUADOR

# %%
panelOLS_models.panel_regression(y, xs, years, "Ecuador", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.989710.
# Adjusted R-squared 0.989533.
# ---------------- Training Results ----------------
# R-squared 0.988754.
# Adjusted R-squared 0.988520.
# ---------------- Overall Results ----------------
# R-squared 0.989302.
# Adjusted R-squared 0.989118.
# ---------------- Training Results ----------------
# R-squared 0.987261.
# Adjusted R-squared 0.986964.
# ---------------- Overall Results ----------------
# R-squared 0.989518.
# Adjusted R-squared 0.989337.
# -------------------- Previous 2 Times --------------------
# R-squared 0.993133.
# Adjusted R-squared 0.993014.
# ---------------- Training Results ----------------
# R-squared 0.992466.
# Adjusted R-squared 0.992309.
# ---------------- Overall Results ----------------
# R-squared 0.992846.
# Adjusted R-squared 0.992723.
# ---------------- Training Results ----------------
# R-squared 0.992006.
# Adjusted R-squared 0.991820.
# ---------------- Overall Results ----------------
# R-squared 0.993089.
# Adjusted R-squared 0.992970.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.993767.
# Adjusted R-squared 0.993659.
# ---------------- Training Results ----------------
# R-squared 0.993104.
# Adjusted R-squared 0.992961.
# ---------------- Overall Results ----------------
# R-squared 0.993465.
# Adjusted R-squared 0.993353.
# ---------------- Training Results ----------------
# R-squared 0.992990.
# Adjusted R-squared 0.992827.
# ---------------- Overall Results ----------------
# R-squared 0.993531.
# Adjusted R-squared 0.993420.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.993204.
# Adjusted R-squared 0.993087.
# ---------------- Training Results ----------------
# R-squared 0.992533.
# Adjusted R-squared 0.992378.
# ---------------- Overall Results ----------------
# R-squared 0.992925.
# Adjusted R-squared 0.992803.
# ---------------- Training Results ----------------
# R-squared 0.992095.
# Adjusted R-squared 0.991911.
# ---------------- Overall Results ----------------
# R-squared 0.993164.
# Adjusted R-squared 0.993046.
# --------------------- k = 5 ---------------------
# R-squared 0.993646.
# Adjusted R-squared 0.993537.
# ---------------- Training Results ----------------
# R-squared 0.993325.
# Adjusted R-squared 0.993186.
# ---------------- Overall Results ----------------
# R-squared 0.993209.
# Adjusted R-squared 0.993092.
# ---------------- Training Results ----------------
# R-squared 0.993133.
# Adjusted R-squared 0.992974.
# ---------------- Overall Results ----------------
# R-squared 0.993465.
# Adjusted R-squared 0.993352.
# --------------------- k = 7 ---------------------
# R-squared 0.993736.
# Adjusted R-squared 0.993628.
# ---------------- Training Results ----------------
# R-squared 0.993420.
# Adjusted R-squared 0.993283.
# ---------------- Overall Results ----------------
# R-squared 0.992748.
# Adjusted R-squared 0.992623.
# ---------------- Training Results ----------------
# R-squared 0.993207.
# Adjusted R-squared 0.993049.
# ---------------- Overall Results ----------------
# R-squared 0.993325.
# Adjusted R-squared 0.993210.
# --------------------- k = 10 ---------------------
# R-squared 0.994491.
# Adjusted R-squared 0.994396.
# ---------------- Training Results ----------------
# R-squared 0.994624.
# Adjusted R-squared 0.994512.
# ---------------- Overall Results ----------------
# R-squared 0.992461.
# Adjusted R-squared 0.992331.
# ---------------- Training Results ----------------
# R-squared 0.994177.
# Adjusted R-squared 0.994042.
# ---------------- Overall Results ----------------
# R-squared 0.993916.
# Adjusted R-squared 0.993811.
# --------------------- k = 15 ---------------------
# R-squared 0.995880.
# Adjusted R-squared 0.995809.
# ---------------- Training Results ----------------
# R-squared 0.995755.
# Adjusted R-squared 0.995667.
# ---------------- Overall Results ----------------
# R-squared 0.994469.
# Adjusted R-squared 0.994374.
# ---------------- Training Results ----------------
# R-squared 0.995813.
# Adjusted R-squared 0.995716.
# ---------------- Overall Results ----------------
# R-squared 0.993871.
# Adjusted R-squared 0.993765.

# %% [markdown]
# ### PERU

# %%
panelOLS_models.panel_regression(y, xs, years, "Peru", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.994597.
# Adjusted R-squared 0.994504.
# ---------------- Training Results ----------------
# R-squared 0.996069.
# Adjusted R-squared 0.995987.
# ---------------- Overall Results ----------------
# R-squared 0.993739.
# Adjusted R-squared 0.993631.
# ---------------- Training Results ----------------
# R-squared 0.995463.
# Adjusted R-squared 0.995357.
# ---------------- Overall Results ----------------
# R-squared 0.993974.
# Adjusted R-squared 0.993871.
# -------------------- Previous 2 Times --------------------
# R-squared 0.995179.
# Adjusted R-squared 0.995095.
# ---------------- Training Results ----------------
# R-squared 0.996212.
# Adjusted R-squared 0.996133.
# ---------------- Overall Results ----------------
# R-squared 0.994255.
# Adjusted R-squared 0.994156.
# ---------------- Training Results ----------------
# R-squared 0.995682.
# Adjusted R-squared 0.995582.
# ---------------- Overall Results ----------------
# R-squared 0.994582.
# Adjusted R-squared 0.994488.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.995679.
# Adjusted R-squared 0.995605.
# ---------------- Training Results ----------------
# R-squared 0.996698.
# Adjusted R-squared 0.996629.
# ---------------- Overall Results ----------------
# R-squared 0.994394.
# Adjusted R-squared 0.994297.
# ---------------- Training Results ----------------
# R-squared 0.996564.
# Adjusted R-squared 0.996484.
# ---------------- Overall Results ----------------
# R-squared 0.994880.
# Adjusted R-squared 0.994792.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.995273.
# Adjusted R-squared 0.995191.
# ---------------- Training Results ----------------
# R-squared 0.996260.
# Adjusted R-squared 0.996182.
# ---------------- Overall Results ----------------
# R-squared 0.994363.
# Adjusted R-squared 0.994266.
# ---------------- Training Results ----------------
# R-squared 0.995761.
# Adjusted R-squared 0.995662.
# ---------------- Overall Results ----------------
# R-squared 0.994710.
# Adjusted R-squared 0.994618.
# --------------------- k = 5 ---------------------
# R-squared 0.995378.
# Adjusted R-squared 0.995298.
# ---------------- Training Results ----------------
# R-squared 0.996794.
# Adjusted R-squared 0.996728.
# ---------------- Overall Results ----------------
# R-squared 0.992227.
# Adjusted R-squared 0.992093.
# ---------------- Training Results ----------------
# R-squared 0.996385.
# Adjusted R-squared 0.996301.
# ---------------- Overall Results ----------------
# R-squared 0.992094.
# Adjusted R-squared 0.991958.
# --------------------- k = 7 ---------------------
# R-squared 0.996227.
# Adjusted R-squared 0.996162.
# ---------------- Training Results ----------------
# R-squared 0.998044.
# Adjusted R-squared 0.998004.
# ---------------- Overall Results ----------------
# R-squared 0.993285.
# Adjusted R-squared 0.993169.
# ---------------- Training Results ----------------
# R-squared 0.997996.
# Adjusted R-squared 0.997950.
# ---------------- Overall Results ----------------
# R-squared 0.993514.
# Adjusted R-squared 0.993402.
# --------------------- k = 10 ---------------------
# R-squared 0.996453.
# Adjusted R-squared 0.996392.
# ---------------- Training Results ----------------
# R-squared 0.998343.
# Adjusted R-squared 0.998309.
# ---------------- Overall Results ----------------
# R-squared 0.993340.
# Adjusted R-squared 0.993226.
# ---------------- Training Results ----------------
# R-squared 0.998135.
# Adjusted R-squared 0.998091.
# ---------------- Overall Results ----------------
# R-squared 0.993476.
# Adjusted R-squared 0.993364.
# --------------------- k = 15 ---------------------
# R-squared 0.997054.
# Adjusted R-squared 0.997003.
# ---------------- Training Results ----------------
# R-squared 0.998678.
# Adjusted R-squared 0.998650.
# ---------------- Overall Results ----------------
# R-squared 0.989343.
# Adjusted R-squared 0.989160.
# ---------------- Training Results ----------------
# R-squared 0.998453.
# Adjusted R-squared 0.998417.
# ---------------- Overall Results ----------------
# R-squared 0.985709.
# Adjusted R-squared 0.985463.

# %% [markdown]
# ### CHINA

# %%
panelOLS_models.panel_regression(y, xs, years, "China", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.994947.
# Adjusted R-squared 0.994860.
# ---------------- Training Results ----------------
# R-squared 0.995002.
# Adjusted R-squared 0.994898.
# ---------------- Overall Results ----------------
# R-squared 0.994415.
# Adjusted R-squared 0.994319.
# ---------------- Training Results ----------------
# R-squared 0.994564.
# Adjusted R-squared 0.994437.
# ---------------- Overall Results ----------------
# R-squared 0.994787.
# Adjusted R-squared 0.994697.
# -------------------- Previous 2 Times --------------------
# R-squared 0.994949.
# Adjusted R-squared 0.994862.
# ---------------- Training Results ----------------
# R-squared 0.995013.
# Adjusted R-squared 0.994909.
# ---------------- Overall Results ----------------
# R-squared 0.994420.
# Adjusted R-squared 0.994324.
# ---------------- Training Results ----------------
# R-squared 0.994575.
# Adjusted R-squared 0.994449.
# ---------------- Overall Results ----------------
# R-squared 0.994774.
# Adjusted R-squared 0.994683.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.995756.
# Adjusted R-squared 0.995683.
# ---------------- Training Results ----------------
# R-squared 0.995565.
# Adjusted R-squared 0.995473.
# ---------------- Overall Results ----------------
# R-squared 0.994545.
# Adjusted R-squared 0.994451.
# ---------------- Training Results ----------------
# R-squared 0.996684.
# Adjusted R-squared 0.996607.
# ---------------- Overall Results ----------------
# R-squared 0.993862.
# Adjusted R-squared 0.993757.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.995489.
# Adjusted R-squared 0.995411.
# ---------------- Training Results ----------------
# R-squared 0.995116.
# Adjusted R-squared 0.995014.
# ---------------- Overall Results ----------------
# R-squared 0.994894.
# Adjusted R-squared 0.994806.
# ---------------- Training Results ----------------
# R-squared 0.995037.
# Adjusted R-squared 0.994922.
# ---------------- Overall Results ----------------
# R-squared 0.995426.
# Adjusted R-squared 0.995347.
# --------------------- k = 5 ---------------------
# R-squared 0.995687.
# Adjusted R-squared 0.995613.
# ---------------- Training Results ----------------
# R-squared 0.995172.
# Adjusted R-squared 0.995071.
# ---------------- Overall Results ----------------
# R-squared 0.994549.
# Adjusted R-squared 0.994455.
# ---------------- Training Results ----------------
# R-squared 0.995705.
# Adjusted R-squared 0.995605.
# ---------------- Overall Results ----------------
# R-squared 0.993196.
# Adjusted R-squared 0.993079.
# --------------------- k = 7 ---------------------
# R-squared 0.995688.
# Adjusted R-squared 0.995614.
# ---------------- Training Results ----------------
# R-squared 0.995444.
# Adjusted R-squared 0.995349.
# ---------------- Overall Results ----------------
# R-squared 0.993245.
# Adjusted R-squared 0.993129.
# ---------------- Training Results ----------------
# R-squared 0.995746.
# Adjusted R-squared 0.995647.
# ---------------- Overall Results ----------------
# R-squared 0.993390.
# Adjusted R-squared 0.993277.
# --------------------- k = 10 ---------------------
# R-squared 0.996502.
# Adjusted R-squared 0.996441.
# ---------------- Training Results ----------------
# R-squared 0.996221.
# Adjusted R-squared 0.996142.
# ---------------- Overall Results ----------------
# R-squared 0.994800.
# Adjusted R-squared 0.994710.
# ---------------- Training Results ----------------
# R-squared 0.996963.
# Adjusted R-squared 0.996892.
# ---------------- Overall Results ----------------
# R-squared 0.990946.
# Adjusted R-squared 0.990790.
# --------------------- k = 15 ---------------------
# R-squared 0.997448.
# Adjusted R-squared 0.997404.
# ---------------- Training Results ----------------
# R-squared 0.997955.
# Adjusted R-squared 0.997913.
# ---------------- Overall Results ----------------
# R-squared 0.992437.
# Adjusted R-squared 0.992306.
# ---------------- Training Results ----------------
# R-squared 0.998217.
# Adjusted R-squared 0.998176.
# ---------------- Overall Results ----------------
# R-squared 0.996325.
# Adjusted R-squared 0.996262.

# %% [markdown]
# ### PHILIPPINES

# %%
panelOLS_models.panel_regression(y, xs, years, "Philippines", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.994743.
# Adjusted R-squared 0.994653.
# ---------------- Training Results ----------------
# R-squared 0.994921.
# Adjusted R-squared 0.994816.
# ---------------- Overall Results ----------------
# R-squared 0.994324.
# Adjusted R-squared 0.994226.
# ---------------- Training Results ----------------
# R-squared 0.996565.
# Adjusted R-squared 0.996485.
# ---------------- Overall Results ----------------
# R-squared 0.994722.
# Adjusted R-squared 0.994631.
# -------------------- Previous 2 Times --------------------
# R-squared 0.994821.
# Adjusted R-squared 0.994731.
# ---------------- Training Results ----------------
# R-squared 0.994924.
# Adjusted R-squared 0.994818.
# ---------------- Overall Results ----------------
# R-squared 0.994277.
# Adjusted R-squared 0.994178.
# ---------------- Training Results ----------------
# R-squared 0.996605.
# Adjusted R-squared 0.996526.
# ---------------- Overall Results ----------------
# R-squared 0.994805.
# Adjusted R-squared 0.994716.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.995259.
# Adjusted R-squared 0.995178.
# ---------------- Training Results ----------------
# R-squared 0.995197.
# Adjusted R-squared 0.995097.
# ---------------- Overall Results ----------------
# R-squared 0.994532.
# Adjusted R-squared 0.994438.
# ---------------- Training Results ----------------
# R-squared 0.997569.
# Adjusted R-squared 0.997512.
# ---------------- Overall Results ----------------
# R-squared 0.994551.
# Adjusted R-squared 0.994457.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.994901.
# Adjusted R-squared 0.994813.
# ---------------- Training Results ----------------
# R-squared 0.994926.
# Adjusted R-squared 0.994820.
# ---------------- Overall Results ----------------
# R-squared 0.994312.
# Adjusted R-squared 0.994214.
# ---------------- Training Results ----------------
# R-squared 0.996709.
# Adjusted R-squared 0.996632.
# ---------------- Overall Results ----------------
# R-squared 0.994899.
# Adjusted R-squared 0.994811.
# --------------------- k = 5 ---------------------
# R-squared 0.994905.
# Adjusted R-squared 0.994817.
# ---------------- Training Results ----------------
# R-squared 0.995120.
# Adjusted R-squared 0.995018.
# ---------------- Overall Results ----------------
# R-squared 0.993969.
# Adjusted R-squared 0.993865.
# ---------------- Training Results ----------------
# R-squared 0.996919.
# Adjusted R-squared 0.996847.
# ---------------- Overall Results ----------------
# R-squared 0.992466.
# Adjusted R-squared 0.992336.
# --------------------- k = 7 ---------------------
# R-squared 0.995193.
# Adjusted R-squared 0.995110.
# ---------------- Training Results ----------------
# R-squared 0.995842.
# Adjusted R-squared 0.995755.
# ---------------- Overall Results ----------------
# R-squared 0.993634.
# Adjusted R-squared 0.993525.
# ---------------- Training Results ----------------
# R-squared 0.997260.
# Adjusted R-squared 0.997196.
# ---------------- Overall Results ----------------
# R-squared 0.993872.
# Adjusted R-squared 0.993766.
# --------------------- k = 10 ---------------------
# R-squared 0.995248.
# Adjusted R-squared 0.995166.
# ---------------- Training Results ----------------
# R-squared 0.996433.
# Adjusted R-squared 0.996359.
# ---------------- Overall Results ----------------
# R-squared 0.991077.
# Adjusted R-squared 0.990923.
# ---------------- Training Results ----------------
# R-squared 0.997866.
# Adjusted R-squared 0.997816.
# ---------------- Overall Results ----------------
# R-squared 0.988208.
# Adjusted R-squared 0.988005.
# --------------------- k = 15 ---------------------
# R-squared 0.996099.
# Adjusted R-squared 0.996031.
# ---------------- Training Results ----------------
# R-squared 0.998160.
# Adjusted R-squared 0.998122.
# ---------------- Overall Results ----------------
# R-squared 0.979649.
# Adjusted R-squared 0.979298.
# ---------------- Training Results ----------------
# R-squared 0.998724.
# Adjusted R-squared 0.998695.
# ---------------- Overall Results ----------------
# R-squared 0.989899.
# Adjusted R-squared 0.989725.
