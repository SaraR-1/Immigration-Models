# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
import numpy as np
from statsmodels.datasets import grunfeld
from linearmodels.panel  import PanelOLS
import pandas as pd
import build_data_functions as bdf
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import model_functions as mf
import plot_model_functions as pmf
import panelOLS_models 
import statsmodels.api as sm
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

# %%
years = list(range(2005, 2016))

# %%
y = pd.read_table("/home/sara/Documents/Immigration/Shared_models/Data/resident_foreigners_norm.csv", sep = "\t", index_col=0)
y = y.groupby(["Province", "Country", "Year"], as_index=False)["Value"].sum()
y = bdf.pivot(y, "Country", "Value")

# %% [markdown]
# ## Zone level

# %%
xs = pd.read_table("/home/sara/Documents/Immigration/Shared_models/Data/x_zones.csv", sep = "\t", index_col=["Province", "Year"])

# %% [markdown]
# #### Feature selection
# Select features according to the k highest scores. The score function used is mutual information.

# %% [markdown]
# ### ROMANIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Romania", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.980167.
# Adjusted R-squared 0.979793.
# ---------------- Training Results ----------------
# R-squared 0.971723.
# Adjusted R-squared 0.971065.
# ---------------- Overall Results ----------------
# R-squared 0.980161.
# Adjusted R-squared 0.979787.
# ---------------- Training Results ----------------
# R-squared 0.965665.
# Adjusted R-squared 0.964761.
# ---------------- Overall Results ----------------
# R-squared 0.980101.
# Adjusted R-squared 0.979726.
# -------------------- Previous 2 Times --------------------
# R-squared 0.981551.
# Adjusted R-squared 0.981203.
# ---------------- Training Results ----------------
# R-squared 0.974041.
# Adjusted R-squared 0.973438.
# ---------------- Overall Results ----------------
# R-squared 0.981545.
# Adjusted R-squared 0.981196.
# ---------------- Training Results ----------------
# R-squared 0.975025.
# Adjusted R-squared 0.974367.
# ---------------- Overall Results ----------------
# R-squared 0.973356.
# Adjusted R-squared 0.972853.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.989604.
# Adjusted R-squared 0.989407.
# ---------------- Training Results ----------------
# R-squared 0.985540.
# Adjusted R-squared 0.985204.
# ---------------- Overall Results ----------------
# R-squared 0.989299.
# Adjusted R-squared 0.989097.
# ---------------- Training Results ----------------
# R-squared 0.986218.
# Adjusted R-squared 0.985855.
# ---------------- Overall Results ----------------
# R-squared 0.979955.
# Adjusted R-squared 0.979576.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.983760.
# Adjusted R-squared 0.983454.
# ---------------- Training Results ----------------
# R-squared 0.977586.
# Adjusted R-squared 0.977064.
# ---------------- Overall Results ----------------
# R-squared 0.983668.
# Adjusted R-squared 0.983360.
# ---------------- Training Results ----------------
# R-squared 0.977577.
# Adjusted R-squared 0.976987.
# ---------------- Overall Results ----------------
# R-squared 0.977072.
# Adjusted R-squared 0.976639.
# --------------------- k = 5 ---------------------
# R-squared 0.985195.
# Adjusted R-squared 0.984915.
# ---------------- Training Results ----------------
# R-squared 0.980007.
# Adjusted R-squared 0.979543.
# ---------------- Overall Results ----------------
# R-squared 0.984950.
# Adjusted R-squared 0.984666.
# ---------------- Training Results ----------------
# R-squared 0.979896.
# Adjusted R-squared 0.979367.
# ---------------- Overall Results ----------------
# R-squared 0.978861.
# Adjusted R-squared 0.978462.
# --------------------- k = 7 ---------------------
# R-squared 0.985496.
# Adjusted R-squared 0.985223.
# ---------------- Training Results ----------------
# R-squared 0.980612.
# Adjusted R-squared 0.980162.
# ---------------- Overall Results ----------------
# R-squared 0.985285.
# Adjusted R-squared 0.985007.
# ---------------- Training Results ----------------
# R-squared 0.980345.
# Adjusted R-squared 0.979828.
# ---------------- Overall Results ----------------
# R-squared 0.979691.
# Adjusted R-squared 0.979307.
# --------------------- k = 10 ---------------------
# R-squared 0.986356.
# Adjusted R-squared 0.986098.
# ---------------- Training Results ----------------
# R-squared 0.982602.
# Adjusted R-squared 0.982198.
# ---------------- Overall Results ----------------
# R-squared 0.985426.
# Adjusted R-squared 0.985151.
# ---------------- Training Results ----------------
# R-squared 0.984895.
# Adjusted R-squared 0.984497.
# ---------------- Overall Results ----------------
# R-squared 0.964318.
# Adjusted R-squared 0.963645.
# --------------------- k = 15 ---------------------
# R-squared 0.988445.
# Adjusted R-squared 0.988227.
# ---------------- Training Results ----------------
# R-squared 0.986433.
# Adjusted R-squared 0.986118.
# ---------------- Overall Results ----------------
# R-squared 0.986486.
# Adjusted R-squared 0.986231.
# ---------------- Training Results ----------------
# R-squared 0.987989.
# Adjusted R-squared 0.987673.
# ---------------- Overall Results ----------------
# R-squared 0.970095.
# Adjusted R-squared 0.969531.

# %% [markdown]
# Using, for Romania, more than 7 features, approximately, leads to overfitting.

# %% [markdown]
# ### MOROCCO

# %%
panelOLS_models.panel_regression(y, xs, years, "Morocco", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.995943.
# Adjusted R-squared 0.995867.
# ---------------- Training Results ----------------
# R-squared 0.995506.
# Adjusted R-squared 0.995401.
# ---------------- Overall Results ----------------
# R-squared 0.995897.
# Adjusted R-squared 0.995820.
# ---------------- Training Results ----------------
# R-squared 0.994830.
# Adjusted R-squared 0.994694.
# ---------------- Overall Results ----------------
# R-squared 0.995890.
# Adjusted R-squared 0.995812.
# -------------------- Previous 2 Times --------------------
# R-squared 0.996324.
# Adjusted R-squared 0.996254.
# ---------------- Training Results ----------------
# R-squared 0.995969.
# Adjusted R-squared 0.995875.
# ---------------- Overall Results ----------------
# R-squared 0.996284.
# Adjusted R-squared 0.996214.
# ---------------- Training Results ----------------
# R-squared 0.997282.
# Adjusted R-squared 0.997211.
# ---------------- Overall Results ----------------
# R-squared 0.989840.
# Adjusted R-squared 0.989648.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.997564.
# Adjusted R-squared 0.997518.
# ---------------- Training Results ----------------
# R-squared 0.997231.
# Adjusted R-squared 0.997166.
# ---------------- Overall Results ----------------
# R-squared 0.997508.
# Adjusted R-squared 0.997461.
# ---------------- Training Results ----------------
# R-squared 0.998185.
# Adjusted R-squared 0.998137.
# ---------------- Overall Results ----------------
# R-squared 0.988689.
# Adjusted R-squared 0.988475.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.996692.
# Adjusted R-squared 0.996630.
# ---------------- Training Results ----------------
# R-squared 0.996314.
# Adjusted R-squared 0.996228.
# ---------------- Overall Results ----------------
# R-squared 0.996659.
# Adjusted R-squared 0.996596.
# ---------------- Training Results ----------------
# R-squared 0.997303.
# Adjusted R-squared 0.997232.
# ---------------- Overall Results ----------------
# R-squared 0.990502.
# Adjusted R-squared 0.990322.
# --------------------- k = 5 ---------------------
# R-squared 0.996904.
# Adjusted R-squared 0.996846.
# ---------------- Training Results ----------------
# R-squared 0.996785.
# Adjusted R-squared 0.996710.
# ---------------- Overall Results ----------------
# R-squared 0.996570.
# Adjusted R-squared 0.996505.
# ---------------- Training Results ----------------
# R-squared 0.997644.
# Adjusted R-squared 0.997581.
# ---------------- Overall Results ----------------
# R-squared 0.990807.
# Adjusted R-squared 0.990633.
# --------------------- k = 7 ---------------------
# R-squared 0.996915.
# Adjusted R-squared 0.996857.
# ---------------- Training Results ----------------
# R-squared 0.996860.
# Adjusted R-squared 0.996787.
# ---------------- Overall Results ----------------
# R-squared 0.996540.
# Adjusted R-squared 0.996474.
# ---------------- Training Results ----------------
# R-squared 0.997920.
# Adjusted R-squared 0.997865.
# ---------------- Overall Results ----------------
# R-squared 0.988394.
# Adjusted R-squared 0.988175.
# --------------------- k = 10 ---------------------
# R-squared 0.997429.
# Adjusted R-squared 0.997381.
# ---------------- Training Results ----------------
# R-squared 0.997764.
# Adjusted R-squared 0.997712.
# ---------------- Overall Results ----------------
# R-squared 0.996983.
# Adjusted R-squared 0.996926.
# ---------------- Training Results ----------------
# R-squared 0.998683.
# Adjusted R-squared 0.998648.
# ---------------- Overall Results ----------------
# R-squared 0.988240.
# Adjusted R-squared 0.988018.
# --------------------- k = 15 ---------------------
# R-squared 0.998519.
# Adjusted R-squared 0.998491.
# ---------------- Training Results ----------------
# R-squared 0.998970.
# Adjusted R-squared 0.998946.
# ---------------- Overall Results ----------------
# R-squared 0.998179.
# Adjusted R-squared 0.998145.
# ---------------- Training Results ----------------
# R-squared 0.999241.
# Adjusted R-squared 0.999221.
# ---------------- Overall Results ----------------
# R-squared 0.989952.
# Adjusted R-squared 0.989762.

# %% [markdown]
# ### ALBANIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Albania", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.996919.
# Adjusted R-squared 0.996861.
# ---------------- Training Results ----------------
# R-squared 0.996594.
# Adjusted R-squared 0.996515.
# ---------------- Overall Results ----------------
# R-squared 0.996884.
# Adjusted R-squared 0.996825.
# ---------------- Training Results ----------------
# R-squared 0.996106.
# Adjusted R-squared 0.996004.
# ---------------- Overall Results ----------------
# R-squared 0.996844.
# Adjusted R-squared 0.996784.
# -------------------- Previous 2 Times --------------------
# R-squared 0.997736.
# Adjusted R-squared 0.997693.
# ---------------- Training Results ----------------
# R-squared 0.997797.
# Adjusted R-squared 0.997746.
# ---------------- Overall Results ----------------
# R-squared 0.997713.
# Adjusted R-squared 0.997670.
# ---------------- Training Results ----------------
# R-squared 0.998728.
# Adjusted R-squared 0.998694.
# ---------------- Overall Results ----------------
# R-squared 0.995739.
# Adjusted R-squared 0.995658.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.998591.
# Adjusted R-squared 0.998565.
# ---------------- Training Results ----------------
# R-squared 0.998549.
# Adjusted R-squared 0.998515.
# ---------------- Overall Results ----------------
# R-squared 0.998557.
# Adjusted R-squared 0.998530.
# ---------------- Training Results ----------------
# R-squared 0.999180.
# Adjusted R-squared 0.999158.
# ---------------- Overall Results ----------------
# R-squared 0.995563.
# Adjusted R-squared 0.995479.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.997789.
# Adjusted R-squared 0.997748.
# ---------------- Training Results ----------------
# R-squared 0.997834.
# Adjusted R-squared 0.997783.
# ---------------- Overall Results ----------------
# R-squared 0.997767.
# Adjusted R-squared 0.997725.
# ---------------- Training Results ----------------
# R-squared 0.998731.
# Adjusted R-squared 0.998698.
# ---------------- Overall Results ----------------
# R-squared 0.995783.
# Adjusted R-squared 0.995703.
# --------------------- k = 5 ---------------------
# R-squared 0.997941.
# Adjusted R-squared 0.997902.
# ---------------- Training Results ----------------
# R-squared 0.997961.
# Adjusted R-squared 0.997914.
# ---------------- Overall Results ----------------
# R-squared 0.997625.
# Adjusted R-squared 0.997580.
# ---------------- Training Results ----------------
# R-squared 0.998942.
# Adjusted R-squared 0.998914.
# ---------------- Overall Results ----------------
# R-squared 0.995046.
# Adjusted R-squared 0.994953.
# --------------------- k = 7 ---------------------
# R-squared 0.998230.
# Adjusted R-squared 0.998196.
# ---------------- Training Results ----------------
# R-squared 0.998360.
# Adjusted R-squared 0.998321.
# ---------------- Overall Results ----------------
# R-squared 0.998144.
# Adjusted R-squared 0.998109.
# ---------------- Training Results ----------------
# R-squared 0.999304.
# Adjusted R-squared 0.999285.
# ---------------- Overall Results ----------------
# R-squared 0.994944.
# Adjusted R-squared 0.994848.
# --------------------- k = 10 ---------------------
# R-squared 0.998238.
# Adjusted R-squared 0.998205.
# ---------------- Training Results ----------------
# R-squared 0.998418.
# Adjusted R-squared 0.998381.
# ---------------- Overall Results ----------------
# R-squared 0.997972.
# Adjusted R-squared 0.997933.
# ---------------- Training Results ----------------
# R-squared 0.999512.
# Adjusted R-squared 0.999499.
# ---------------- Overall Results ----------------
# R-squared 0.993839.
# Adjusted R-squared 0.993723.
# --------------------- k = 15 ---------------------
# R-squared 0.999178.
# Adjusted R-squared 0.999163.
# ---------------- Training Results ----------------
# R-squared 0.999498.
# Adjusted R-squared 0.999487.
# ---------------- Overall Results ----------------
# R-squared 0.999001.
# Adjusted R-squared 0.998983.
# ---------------- Training Results ----------------
# R-squared 0.999607.
# Adjusted R-squared 0.999597.
# ---------------- Overall Results ----------------
# R-squared 0.997251.
# Adjusted R-squared 0.997199.

# %% [markdown]
# ### TUNISIA

# %%
panelOLS_models.panel_regression(y, xs, years, "Tunisia", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.990285.
# Adjusted R-squared 0.990102.
# ---------------- Training Results ----------------
# R-squared 0.988953.
# Adjusted R-squared 0.988696.
# ---------------- Overall Results ----------------
# R-squared 0.990278.
# Adjusted R-squared 0.990095.
# ---------------- Training Results ----------------
# R-squared 0.987958.
# Adjusted R-squared 0.987641.
# ---------------- Overall Results ----------------
# R-squared 0.990240.
# Adjusted R-squared 0.990056.
# -------------------- Previous 2 Times --------------------
# R-squared 0.990403.
# Adjusted R-squared 0.990222.
# ---------------- Training Results ----------------
# R-squared 0.989114.
# Adjusted R-squared 0.988861.
# ---------------- Overall Results ----------------
# R-squared 0.990399.
# Adjusted R-squared 0.990218.
# ---------------- Training Results ----------------
# R-squared 0.993407.
# Adjusted R-squared 0.993233.
# ---------------- Overall Results ----------------
# R-squared 0.956998.
# Adjusted R-squared 0.956187.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.994214.
# Adjusted R-squared 0.994105.
# ---------------- Training Results ----------------
# R-squared 0.993974.
# Adjusted R-squared 0.993834.
# ---------------- Overall Results ----------------
# R-squared 0.993794.
# Adjusted R-squared 0.993677.
# ---------------- Training Results ----------------
# R-squared 0.995711.
# Adjusted R-squared 0.995598.
# ---------------- Overall Results ----------------
# R-squared 0.973412.
# Adjusted R-squared 0.972911.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.990696.
# Adjusted R-squared 0.990520.
# ---------------- Training Results ----------------
# R-squared 0.989639.
# Adjusted R-squared 0.989398.
# ---------------- Overall Results ----------------
# R-squared 0.990653.
# Adjusted R-squared 0.990477.
# ---------------- Training Results ----------------
# R-squared 0.993409.
# Adjusted R-squared 0.993236.
# ---------------- Overall Results ----------------
# R-squared 0.957499.
# Adjusted R-squared 0.956697.
# --------------------- k = 5 ---------------------
# R-squared 0.990962.
# Adjusted R-squared 0.990791.
# ---------------- Training Results ----------------
# R-squared 0.990672.
# Adjusted R-squared 0.990455.
# ---------------- Overall Results ----------------
# R-squared 0.990240.
# Adjusted R-squared 0.990056.
# ---------------- Training Results ----------------
# R-squared 0.994756.
# Adjusted R-squared 0.994618.
# ---------------- Overall Results ----------------
# R-squared 0.955809.
# Adjusted R-squared 0.954976.
# --------------------- k = 7 ---------------------
# R-squared 0.992983.
# Adjusted R-squared 0.992851.
# ---------------- Training Results ----------------
# R-squared 0.993659.
# Adjusted R-squared 0.993512.
# ---------------- Overall Results ----------------
# R-squared 0.992600.
# Adjusted R-squared 0.992460.
# ---------------- Training Results ----------------
# R-squared 0.996467.
# Adjusted R-squared 0.996374.
# ---------------- Overall Results ----------------
# R-squared 0.973195.
# Adjusted R-squared 0.972689.
# --------------------- k = 10 ---------------------
# R-squared 0.993659.
# Adjusted R-squared 0.993539.
# ---------------- Training Results ----------------
# R-squared 0.994739.
# Adjusted R-squared 0.994616.
# ---------------- Overall Results ----------------
# R-squared 0.992505.
# Adjusted R-squared 0.992364.
# ---------------- Training Results ----------------
# R-squared 0.996731.
# Adjusted R-squared 0.996645.
# ---------------- Overall Results ----------------
# R-squared 0.976292.
# Adjusted R-squared 0.975844.
# --------------------- k = 15 ---------------------
# R-squared 0.995174.
# Adjusted R-squared 0.995083.
# ---------------- Training Results ----------------
# R-squared 0.997263.
# Adjusted R-squared 0.997200.
# ---------------- Overall Results ----------------
# R-squared 0.992626.
# Adjusted R-squared 0.992487.
# ---------------- Training Results ----------------
# R-squared 0.998564.
# Adjusted R-squared 0.998526.
# ---------------- Overall Results ----------------
# R-squared 0.976952.
# Adjusted R-squared 0.976517.

# %% [markdown]
# ### EGYPT

# %%
panelOLS_models.panel_regression(y, xs, years, "Egypt", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.981399.
# Adjusted R-squared 0.981048.
# ---------------- Training Results ----------------
# R-squared 0.978226.
# Adjusted R-squared 0.977720.
# ---------------- Overall Results ----------------
# R-squared 0.980864.
# Adjusted R-squared 0.980503.
# ---------------- Training Results ----------------
# R-squared 0.976349.
# Adjusted R-squared 0.975726.
# ---------------- Overall Results ----------------
# R-squared 0.980205.
# Adjusted R-squared 0.979832.
# -------------------- Previous 2 Times --------------------
# R-squared 0.981457.
# Adjusted R-squared 0.981107.
# ---------------- Training Results ----------------
# R-squared 0.978689.
# Adjusted R-squared 0.978194.
# ---------------- Overall Results ----------------
# R-squared 0.980568.
# Adjusted R-squared 0.980201.
# ---------------- Training Results ----------------
# R-squared 0.977508.
# Adjusted R-squared 0.976916.
# ---------------- Overall Results ----------------
# R-squared 0.969831.
# Adjusted R-squared 0.969262.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.983097.
# Adjusted R-squared 0.982778.
# ---------------- Training Results ----------------
# R-squared 0.982664.
# Adjusted R-squared 0.982261.
# ---------------- Overall Results ----------------
# R-squared 0.977348.
# Adjusted R-squared 0.976921.
# ---------------- Training Results ----------------
# R-squared 0.983066.
# Adjusted R-squared 0.982620.
# ---------------- Overall Results ----------------
# R-squared 0.954547.
# Adjusted R-squared 0.953689.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.981652.
# Adjusted R-squared 0.981306.
# ---------------- Training Results ----------------
# R-squared 0.978997.
# Adjusted R-squared 0.978509.
# ---------------- Overall Results ----------------
# R-squared 0.980711.
# Adjusted R-squared 0.980347.
# ---------------- Training Results ----------------
# R-squared 0.977772.
# Adjusted R-squared 0.977187.
# ---------------- Overall Results ----------------
# R-squared 0.970678.
# Adjusted R-squared 0.970125.
# --------------------- k = 5 ---------------------
# R-squared 0.982686.
# Adjusted R-squared 0.982359.
# ---------------- Training Results ----------------
# R-squared 0.980202.
# Adjusted R-squared 0.979742.
# ---------------- Overall Results ----------------
# R-squared 0.982210.
# Adjusted R-squared 0.981874.
# ---------------- Training Results ----------------
# R-squared 0.979677.
# Adjusted R-squared 0.979142.
# ---------------- Overall Results ----------------
# R-squared 0.967914.
# Adjusted R-squared 0.967309.
# --------------------- k = 7 ---------------------
# R-squared 0.985007.
# Adjusted R-squared 0.984724.
# ---------------- Training Results ----------------
# R-squared 0.985032.
# Adjusted R-squared 0.984684.
# ---------------- Overall Results ----------------
# R-squared 0.980871.
# Adjusted R-squared 0.980511.
# ---------------- Training Results ----------------
# R-squared 0.986980.
# Adjusted R-squared 0.986637.
# ---------------- Overall Results ----------------
# R-squared 0.960405.
# Adjusted R-squared 0.959658.
# --------------------- k = 10 ---------------------
# R-squared 0.985863.
# Adjusted R-squared 0.985596.
# ---------------- Training Results ----------------
# R-squared 0.985980.
# Adjusted R-squared 0.985654.
# ---------------- Overall Results ----------------
# R-squared 0.970407.
# Adjusted R-squared 0.969848.
# ---------------- Training Results ----------------
# R-squared 0.991263.
# Adjusted R-squared 0.991033.
# ---------------- Overall Results ----------------
# R-squared 0.888287.
# Adjusted R-squared 0.886179.
# --------------------- k = 15 ---------------------
# R-squared 0.987385.
# Adjusted R-squared 0.987146.
# ---------------- Training Results ----------------
# R-squared 0.988055.
# Adjusted R-squared 0.987778.
# ---------------- Overall Results ----------------
# R-squared 0.964755.
# Adjusted R-squared 0.964090.
# ---------------- Training Results ----------------
# R-squared 0.992402.
# Adjusted R-squared 0.992202.
# ---------------- Overall Results ----------------
# R-squared 0.859593.
# Adjusted R-squared 0.856944.

# %% [markdown]
# ### ECUADOR

# %%
panelOLS_models.panel_regression(y, xs, years, "Ecuador", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.989610.
# Adjusted R-squared 0.989414.
# ---------------- Training Results ----------------
# R-squared 0.987261.
# Adjusted R-squared 0.986964.
# ---------------- Overall Results ----------------
# R-squared 0.989603.
# Adjusted R-squared 0.989407.
# ---------------- Training Results ----------------
# R-squared 0.985442.
# Adjusted R-squared 0.985059.
# ---------------- Overall Results ----------------
# R-squared 0.989562.
# Adjusted R-squared 0.989365.
# -------------------- Previous 2 Times --------------------
# R-squared 0.992690.
# Adjusted R-squared 0.992552.
# ---------------- Training Results ----------------
# R-squared 0.992006.
# Adjusted R-squared 0.991820.
# ---------------- Overall Results ----------------
# R-squared 0.992662.
# Adjusted R-squared 0.992524.
# ---------------- Training Results ----------------
# R-squared 0.993083.
# Adjusted R-squared 0.992901.
# ---------------- Overall Results ----------------
# R-squared 0.990642.
# Adjusted R-squared 0.990465.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.993493.
# Adjusted R-squared 0.993370.
# ---------------- Training Results ----------------
# R-squared 0.992660.
# Adjusted R-squared 0.992490.
# ---------------- Overall Results ----------------
# R-squared 0.993199.
# Adjusted R-squared 0.993070.
# ---------------- Training Results ----------------
# R-squared 0.994144.
# Adjusted R-squared 0.993990.
# ---------------- Overall Results ----------------
# R-squared 0.985346.
# Adjusted R-squared 0.985070.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.992769.
# Adjusted R-squared 0.992633.
# ---------------- Training Results ----------------
# R-squared 0.992095.
# Adjusted R-squared 0.991911.
# ---------------- Overall Results ----------------
# R-squared 0.992742.
# Adjusted R-squared 0.992605.
# ---------------- Training Results ----------------
# R-squared 0.993105.
# Adjusted R-squared 0.992924.
# ---------------- Overall Results ----------------
# R-squared 0.990738.
# Adjusted R-squared 0.990564.
# --------------------- k = 5 ---------------------
# R-squared 0.992775.
# Adjusted R-squared 0.992639.
# ---------------- Training Results ----------------
# R-squared 0.992263.
# Adjusted R-squared 0.992083.
# ---------------- Overall Results ----------------
# R-squared 0.992526.
# Adjusted R-squared 0.992385.
# ---------------- Training Results ----------------
# R-squared 0.993800.
# Adjusted R-squared 0.993637.
# ---------------- Overall Results ----------------
# R-squared 0.989782.
# Adjusted R-squared 0.989589.
# --------------------- k = 7 ---------------------
# R-squared 0.993370.
# Adjusted R-squared 0.993244.
# ---------------- Training Results ----------------
# R-squared 0.993207.
# Adjusted R-squared 0.993049.
# ---------------- Overall Results ----------------
# R-squared 0.993128.
# Adjusted R-squared 0.992999.
# ---------------- Training Results ----------------
# R-squared 0.995831.
# Adjusted R-squared 0.995721.
# ---------------- Overall Results ----------------
# R-squared 0.988286.
# Adjusted R-squared 0.988065.
# --------------------- k = 10 ---------------------
# R-squared 0.993517.
# Adjusted R-squared 0.993395.
# ---------------- Training Results ----------------
# R-squared 0.993304.
# Adjusted R-squared 0.993148.
# ---------------- Overall Results ----------------
# R-squared 0.993259.
# Adjusted R-squared 0.993132.
# ---------------- Training Results ----------------
# R-squared 0.997026.
# Adjusted R-squared 0.996948.
# ---------------- Overall Results ----------------
# R-squared 0.969714.
# Adjusted R-squared 0.969143.
# --------------------- k = 15 ---------------------
# R-squared 0.995446.
# Adjusted R-squared 0.995360.
# ---------------- Training Results ----------------
# R-squared 0.995148.
# Adjusted R-squared 0.995035.
# ---------------- Overall Results ----------------
# R-squared 0.993954.
# Adjusted R-squared 0.993840.
# ---------------- Training Results ----------------
# R-squared 0.997531.
# Adjusted R-squared 0.997466.
# ---------------- Overall Results ----------------
# R-squared 0.963093.
# Adjusted R-squared 0.962396.

# %% [markdown]
# ### PERU

# %%
panelOLS_models.panel_regression(y, xs, years, "Peru", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.995936.
# Adjusted R-squared 0.995860.
# ---------------- Training Results ----------------
# R-squared 0.995463.
# Adjusted R-squared 0.995357.
# ---------------- Overall Results ----------------
# R-squared 0.995882.
# Adjusted R-squared 0.995804.
# ---------------- Training Results ----------------
# R-squared 0.994662.
# Adjusted R-squared 0.994522.
# ---------------- Overall Results ----------------
# R-squared 0.995794.
# Adjusted R-squared 0.995715.
# -------------------- Previous 2 Times --------------------
# R-squared 0.995995.
# Adjusted R-squared 0.995919.
# ---------------- Training Results ----------------
# R-squared 0.995682.
# Adjusted R-squared 0.995582.
# ---------------- Overall Results ----------------
# R-squared 0.995922.
# Adjusted R-squared 0.995845.
# ---------------- Training Results ----------------
# R-squared 0.994875.
# Adjusted R-squared 0.994740.
# ---------------- Overall Results ----------------
# R-squared 0.995776.
# Adjusted R-squared 0.995696.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.996629.
# Adjusted R-squared 0.996566.
# ---------------- Training Results ----------------
# R-squared 0.996368.
# Adjusted R-squared 0.996284.
# ---------------- Overall Results ----------------
# R-squared 0.996460.
# Adjusted R-squared 0.996394.
# ---------------- Training Results ----------------
# R-squared 0.996171.
# Adjusted R-squared 0.996070.
# ---------------- Overall Results ----------------
# R-squared 0.993742.
# Adjusted R-squared 0.993624.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.996069.
# Adjusted R-squared 0.995995.
# ---------------- Training Results ----------------
# R-squared 0.995761.
# Adjusted R-squared 0.995662.
# ---------------- Overall Results ----------------
# R-squared 0.996004.
# Adjusted R-squared 0.995929.
# ---------------- Training Results ----------------
# R-squared 0.994966.
# Adjusted R-squared 0.994833.
# ---------------- Overall Results ----------------
# R-squared 0.995865.
# Adjusted R-squared 0.995787.
# --------------------- k = 5 ---------------------
# R-squared 0.996085.
# Adjusted R-squared 0.996011.
# ---------------- Training Results ----------------
# R-squared 0.996385.
# Adjusted R-squared 0.996301.
# ---------------- Overall Results ----------------
# R-squared 0.994934.
# Adjusted R-squared 0.994838.
# ---------------- Training Results ----------------
# R-squared 0.995863.
# Adjusted R-squared 0.995754.
# ---------------- Overall Results ----------------
# R-squared 0.994497.
# Adjusted R-squared 0.994393.
# --------------------- k = 7 ---------------------
# R-squared 0.997554.
# Adjusted R-squared 0.997508.
# ---------------- Training Results ----------------
# R-squared 0.997888.
# Adjusted R-squared 0.997839.
# ---------------- Overall Results ----------------
# R-squared 0.996992.
# Adjusted R-squared 0.996935.
# ---------------- Training Results ----------------
# R-squared 0.998132.
# Adjusted R-squared 0.998083.
# ---------------- Overall Results ----------------
# R-squared 0.995861.
# Adjusted R-squared 0.995783.
# --------------------- k = 10 ---------------------
# R-squared 0.998008.
# Adjusted R-squared 0.997971.
# ---------------- Training Results ----------------
# R-squared 0.998208.
# Adjusted R-squared 0.998166.
# ---------------- Overall Results ----------------
# R-squared 0.996598.
# Adjusted R-squared 0.996534.
# ---------------- Training Results ----------------
# R-squared 0.998341.
# Adjusted R-squared 0.998297.
# ---------------- Overall Results ----------------
# R-squared 0.994838.
# Adjusted R-squared 0.994741.
# --------------------- k = 15 ---------------------
# R-squared 0.998172.
# Adjusted R-squared 0.998137.
# ---------------- Training Results ----------------
# R-squared 0.998301.
# Adjusted R-squared 0.998261.
# ---------------- Overall Results ----------------
# R-squared 0.996527.
# Adjusted R-squared 0.996462.
# ---------------- Training Results ----------------
# R-squared 0.998655.
# Adjusted R-squared 0.998620.
# ---------------- Overall Results ----------------
# R-squared 0.990819.
# Adjusted R-squared 0.990646.

# %% [markdown]
# ### CHINA

# %%
panelOLS_models.panel_regression(y, xs, years, "China", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.994832.
# Adjusted R-squared 0.994735.
# ---------------- Training Results ----------------
# R-squared 0.994564.
# Adjusted R-squared 0.994437.
# ---------------- Overall Results ----------------
# R-squared 0.994828.
# Adjusted R-squared 0.994731.
# ---------------- Training Results ----------------
# R-squared 0.993949.
# Adjusted R-squared 0.993790.
# ---------------- Overall Results ----------------
# R-squared 0.994777.
# Adjusted R-squared 0.994679.
# -------------------- Previous 2 Times --------------------
# R-squared 0.994864.
# Adjusted R-squared 0.994767.
# ---------------- Training Results ----------------
# R-squared 0.994575.
# Adjusted R-squared 0.994449.
# ---------------- Overall Results ----------------
# R-squared 0.994855.
# Adjusted R-squared 0.994758.
# ---------------- Training Results ----------------
# R-squared 0.994654.
# Adjusted R-squared 0.994513.
# ---------------- Overall Results ----------------
# R-squared 0.992443.
# Adjusted R-squared 0.992300.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.996197.
# Adjusted R-squared 0.996125.
# ---------------- Training Results ----------------
# R-squared 0.996696.
# Adjusted R-squared 0.996619.
# ---------------- Overall Results ----------------
# R-squared 0.994000.
# Adjusted R-squared 0.993886.
# ---------------- Training Results ----------------
# R-squared 0.997498.
# Adjusted R-squared 0.997432.
# ---------------- Overall Results ----------------
# R-squared 0.987824.
# Adjusted R-squared 0.987594.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.995181.
# Adjusted R-squared 0.995091.
# ---------------- Training Results ----------------
# R-squared 0.994856.
# Adjusted R-squared 0.994737.
# ---------------- Overall Results ----------------
# R-squared 0.995101.
# Adjusted R-squared 0.995009.
# ---------------- Training Results ----------------
# R-squared 0.994867.
# Adjusted R-squared 0.994732.
# ---------------- Overall Results ----------------
# R-squared 0.993287.
# Adjusted R-squared 0.993161.
# --------------------- k = 5 ---------------------
# R-squared 0.995385.
# Adjusted R-squared 0.995298.
# ---------------- Training Results ----------------
# R-squared 0.995705.
# Adjusted R-squared 0.995605.
# ---------------- Overall Results ----------------
# R-squared 0.992117.
# Adjusted R-squared 0.991969.
# ---------------- Training Results ----------------
# R-squared 0.996009.
# Adjusted R-squared 0.995904.
# ---------------- Overall Results ----------------
# R-squared 0.989332.
# Adjusted R-squared 0.989131.
# --------------------- k = 7 ---------------------
# R-squared 0.996044.
# Adjusted R-squared 0.995969.
# ---------------- Training Results ----------------
# R-squared 0.996940.
# Adjusted R-squared 0.996868.
# ---------------- Overall Results ----------------
# R-squared 0.991066.
# Adjusted R-squared 0.990897.
# ---------------- Training Results ----------------
# R-squared 0.997272.
# Adjusted R-squared 0.997200.
# ---------------- Overall Results ----------------
# R-squared 0.990919.
# Adjusted R-squared 0.990747.
# --------------------- k = 10 ---------------------
# R-squared 0.996298.
# Adjusted R-squared 0.996228.
# ---------------- Training Results ----------------
# R-squared 0.997206.
# Adjusted R-squared 0.997141.
# ---------------- Overall Results ----------------
# R-squared 0.992239.
# Adjusted R-squared 0.992092.
# ---------------- Training Results ----------------
# R-squared 0.997704.
# Adjusted R-squared 0.997644.
# ---------------- Overall Results ----------------
# R-squared 0.992401.
# Adjusted R-squared 0.992258.
# --------------------- k = 15 ---------------------
# R-squared 0.997028.
# Adjusted R-squared 0.996972.
# ---------------- Training Results ----------------
# R-squared 0.998156.
# Adjusted R-squared 0.998113.
# ---------------- Overall Results ----------------
# R-squared 0.995167.
# Adjusted R-squared 0.995076.
# ---------------- Training Results ----------------
# R-squared 0.999051.
# Adjusted R-squared 0.999026.
# ---------------- Overall Results ----------------
# R-squared 0.991993.
# Adjusted R-squared 0.991842.

# %% [markdown]
# ### PHILIPPINES

# %%
panelOLS_models.panel_regression(y, xs, years, "Philippines", [3, 5, 7, 10, 15], save = False, show = False)
# Out:
# --------------------- Previous  Time ---------------------
# R-squared 0.994925.
# Adjusted R-squared 0.994829.
# ---------------- Training Results ----------------
# R-squared 0.996565.
# Adjusted R-squared 0.996485.
# ---------------- Overall Results ----------------
# R-squared 0.994864.
# Adjusted R-squared 0.994768.
# ---------------- Training Results ----------------
# R-squared 0.996044.
# Adjusted R-squared 0.995940.
# ---------------- Overall Results ----------------
# R-squared 0.994807.
# Adjusted R-squared 0.994709.
# -------------------- Previous 2 Times --------------------
# R-squared 0.995188.
# Adjusted R-squared 0.995097.
# ---------------- Training Results ----------------
# R-squared 0.996605.
# Adjusted R-squared 0.996526.
# ---------------- Overall Results ----------------
# R-squared 0.995010.
# Adjusted R-squared 0.994916.
# ---------------- Training Results ----------------
# R-squared 0.996045.
# Adjusted R-squared 0.995941.
# ---------------- Overall Results ----------------
# R-squared 0.994847.
# Adjusted R-squared 0.994749.
# ------------- Variable Selection  Plot based -------------
# R-squared 0.995490.
# Adjusted R-squared 0.995405.
# ---------------- Training Results ----------------
# R-squared 0.997394.
# Adjusted R-squared 0.997333.
# ---------------- Overall Results ----------------
# R-squared 0.994006.
# Adjusted R-squared 0.993893.
# ---------------- Training Results ----------------
# R-squared 0.997502.
# Adjusted R-squared 0.997436.
# ---------------- Overall Results ----------------
# R-squared 0.989584.
# Adjusted R-squared 0.989388.
# ----------------- Variable Selection  MI -----------------
# --------------------- k = 3 ---------------------
# R-squared 0.995200.
# Adjusted R-squared 0.995110.
# ---------------- Training Results ----------------
# R-squared 0.996611.
# Adjusted R-squared 0.996532.
# ---------------- Overall Results ----------------
# R-squared 0.994991.
# Adjusted R-squared 0.994896.
# ---------------- Training Results ----------------
# R-squared 0.996060.
# Adjusted R-squared 0.995956.
# ---------------- Overall Results ----------------
# R-squared 0.994824.
# Adjusted R-squared 0.994726.
# --------------------- k = 5 ---------------------
# R-squared 0.995290.
# Adjusted R-squared 0.995201.
# ---------------- Training Results ----------------
# R-squared 0.996919.
# Adjusted R-squared 0.996847.
# ---------------- Overall Results ----------------
# R-squared 0.993354.
# Adjusted R-squared 0.993228.
# ---------------- Training Results ----------------
# R-squared 0.996473.
# Adjusted R-squared 0.996380.
# ---------------- Overall Results ----------------
# R-squared 0.992705.
# Adjusted R-squared 0.992568.
# --------------------- k = 7 ---------------------
# R-squared 0.995807.
# Adjusted R-squared 0.995728.
# ---------------- Training Results ----------------
# R-squared 0.997260.
# Adjusted R-squared 0.997196.
# ---------------- Overall Results ----------------
# R-squared 0.994721.
# Adjusted R-squared 0.994622.
# ---------------- Training Results ----------------
# R-squared 0.996817.
# Adjusted R-squared 0.996733.
# ---------------- Overall Results ----------------
# R-squared 0.994322.
# Adjusted R-squared 0.994215.
# --------------------- k = 10 ---------------------
# R-squared 0.996209.
# Adjusted R-squared 0.996138.
# ---------------- Training Results ----------------
# R-squared 0.998603.
# Adjusted R-squared 0.998571.
# ---------------- Overall Results ----------------
# R-squared 0.991794.
# Adjusted R-squared 0.991639.
# ---------------- Training Results ----------------
# R-squared 0.998616.
# Adjusted R-squared 0.998579.
# ---------------- Overall Results ----------------
# R-squared 0.991763.
# Adjusted R-squared 0.991607.
# --------------------- k = 15 ---------------------
# R-squared 0.996762.
# Adjusted R-squared 0.996701.
# ---------------- Training Results ----------------
# R-squared 0.998725.
# Adjusted R-squared 0.998695.
# ---------------- Overall Results ----------------
# R-squared 0.993683.
# Adjusted R-squared 0.993564.
# ---------------- Training Results ----------------
# R-squared 0.998808.
# Adjusted R-squared 0.998777.
# ---------------- Overall Results ----------------
# R-squared 0.994404.
# Adjusted R-squared 0.994299.
